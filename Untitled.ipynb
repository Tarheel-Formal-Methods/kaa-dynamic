# %%
from IPython.display import Image, Video

# %% [markdown]
# # This week
# - Sanity check of pre-generated directions
# - PCA Sliding Window
# - Building on top of 1 step PCA/Lin App

# %% [markdown]
# # 2-Combinations of Strategies

# %%
Image("figures/12:18:20/CombinationsofVDP(Lin App 1 Step).png")

# %%
Image("figures/12:18:20/CombinationsofVDP.png")

# %% [markdown]
# # PCA Sliding Window

# %%
Image("figures/12:18:20/PCALifeSpan.png")
