# %%
from IPython.display import Image

# %% [markdown]
# # Vanderpol ($\Delta = 0.08$, 70 steps)

# %% [markdown]
# ## VDP Volume plot for 20 Sliding Dynamic Strategies

# %%
Image("figures/FinalSheets/VDP(Supp)/VolComp/VDPSlidingStratVolumePlot.png")

# %% [markdown]
# ## VDP Volume plot for 5 Sliding Dynamic Strategies

# %% [markdown]
# Sapo uses 5 non-trivial templates. We perform the same experiment as above but restrict the number of dynamic templates to five.

# %%
Image("figures/FinalSheets/VDP(Supp)/VolComp/VDPSlidingStratVolumePlot(Sapo, 5 temps).png")

# %% [markdown]
# ## VDP Volume of Initial Box VS Volume of Reachable Set with 20 Dynamic Templates

# %%
Image("figures/FinalSheets/VDP(Supp)/InitReachVol/VDPInitReachVol(70 steps).png")

# %% [markdown]
# # VDP Volume of Initial Box VS Volume of Reachable Set with 5 Dynamic Templates

# %%
Image("figures/FinalSheets/VDP(Supp)/InitReachVol/VDPInitReachVol(70 steps, 5temps).png")

# %% [markdown]
# # JetEngine ($\Delta = 0.2$, 100 steps)

# %% [markdown]
# ## JetEngine Sample plot (10 PCA, 10 LinApp, $\Delta = 0.1$)

# %%
Image("figures/FinalSheets/JetEngine(SUPP)/10Pca10Lin(100 steps delta=0.1).png")

# %% [markdown]
# ## JetEngine Volume plot for 20 Sliding Dynamic Strategies

# %%
Image("figures/FinalSheets/JetEngine(SUPP)/VolComp/VolCompJetEngine(SlidingStratComb).png")

# %% [markdown]
# ## JetEngine Volume plot for 5 Sliding Dynamic Strategies VS Sapo

# %%
Image("figures/FinalSheets/JetEngine(SUPP)/VolComp/VolCompJetEngine(Sapo,5temps).png")

# %% [markdown]
# ## JetEngine Volume of Initial Box VS Volume of Reachable Set with 20 Dynamic Templates

# %%
Image("figures/FinalSheets/JetEngine(SUPP)/InitReachVol/JetEngineInitReachVol(100 steps).png")

# %% [markdown]
# ## JetEngine Volume of Initial Box VS Volume of Reachable Set with 5 Dynamic Templates

# %%
Image("figures/FinalSheets/JetEngine(SUPP)/InitReachVol/JetEngineInitReachVol(100 steps, 5temp).png")

# %% [markdown]
# # FitzHugh-Nagumo Neuron ($\Delta = 0.2$, 500 steps)

# %% [markdown]
# ## Neuron Sample plot (10 PCA, 10 LinApp)

# %%
Image("figures/FinalSheets/Neuron(SUPP)/VolComp/VolCompNeuron(500Steps).png")

# %% [markdown]
# # SIR ($\Delta = 0.1$, 150 steps)

# %% [markdown]
# ## SIR Volume of Initial Box VS Volume of Reachable Set with 20 Dynamic Templates

# %% [markdown]
# Plots warped due to extreme differences in orders of magnitude between Sapo volume and Kaa volume

# %%
Image("figures/FinalSheets/SIR(SUPP)/InitReachVol/SIRInitReachVol(150steps).png")
