# %%
from IPython.display import Image, Video

# %% [markdown]
# # 2 PCA Templates, 2 LinApp Templates with Box

# %%
Image("figures/11:26:20/VDPSapoVSKaa(2 Lin Temp. - 2 PCA temp)(Trial 1).png")

# %%
Image("figures/11:26:20/VDPSapoVSKaa(2 Lin Temp. - 2 PCA temp)(Trial 2).png")

# %%
Image("figures/11:26:20/VDPSapoVSKaa(2 Lin Temp. - 2 PCA temp)(Trial 3).png")

# %% [markdown]
# # 3 PCA Templates with Box

# %%
Image("figures/11:26:20/VDPKaaPCA(3 Temp)(Trial 1).png")

# %%
Image("figures/11:26:20/VDPKaaPCA(3 Temp)(Trial 2).png")

# %%
Image("figures/11:26:20/VDPKaaPCA(3 Temp)(Trial 3).png")

# %% [markdown]
# # 3 LinApp Templates with Box

# %%
Image("figures/11:26:20/VDPKaaLin(3 Temp)(Trial 1).png")

# %%
Image("figures/11:26:20/VDPKaaLin(3 Temp)(Trial 2).png")

# %%
Image("figures/11:26:20/VDPKaaLin(3 Temp)(Trial 3).png")
